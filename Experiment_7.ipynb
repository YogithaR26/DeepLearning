# %% [markdown]
# <a href="https://colab.research.google.com/github/YogithaR26/DeepLearning/blob/main/Experiment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras.datasets import cifar10

# %%
(X_train,y_train) , (X_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
# ...

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(X_train[0])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(40,40))

num_images = 20
for i in range(num_images):
    row = X_train[i]
    label = y_train[i]

    image = row
    plt.subplot(1, num_images, i+1)
    plt.title(label, fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(image, cmap='gray')

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
X_train/=255
X_test/=255

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread('flower.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=640x462>

# %%
import matplotlib.pyplot as plt
equ = cv2.equalizeHist(img)
cv2_imshow(equ)
# Out:
# <PIL.Image.Image image mode=L size=640x462>

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
)
datagen.fit(X_train)

# %%
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].astype(np.uint8))
    plt.show()
    break

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('flower.jpg')
threshold_value = 120
max_val = 255
ret, image = cv2.threshold(image, threshold_value, max_val, cv2.THRESH_BINARY)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x462>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('flower.jpg',0)
ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread("flower.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x462>

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")
plt.show()

# %%
edges = cv2.Canny(gray, threshold1=30, threshold2=100)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=640x462>
